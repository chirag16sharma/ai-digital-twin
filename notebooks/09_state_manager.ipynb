# %%
from pathlib import Path
import sys

project_root = Path.cwd().parent

sys.path.append(str(project_root))

from src.twin.state_manager import StateManager

# %%
state = StateManager()

# %%
state.display_state()

# %%
state.set_date("2025-07-15")

state.display_state()

# %%
state.set_location(
    12.9716,
    77.5946
)

state.display_state()

# %%
state.update_state(
    latitude=28.6139,
    longitude=77.2090,
    date="2025-08-10",
    rainfall=45.8
)

state.display_state()

# %%
state.clear_state()

state.display_state()

# %%
state.set_date("2025-07-15")

state.display_state()

# %%
state.get_state()
