# %%
from pathlib import Path
import sys

project_root = Path.cwd().parent

sys.path.append(str(project_root))

from src.twin.digital_twin import DigitalTwin

# %%
twin = DigitalTwin(
    project_root /
    "data" /
    "raw" /
    "imd_rainfall" /
    "rainfall2025.nc"
)

# %%
result = twin.rainfall(
    12.9716,
    77.5946,
    "2025-07-15"
)

result
# Out:
# {'latitude': np.float64(13.0),
#  'longitude': np.float64(77.5),
#  'date': '2025-07-15',
#  'rainfall': 0.0}

# %%
twin.current_state()
# Out:
# {'latitude': np.float64(13.0),
#  'longitude': np.float64(77.5),
#  'date': '2025-07-15',
#  'rainfall': 0.0,
#  'last_updated': datetime.datetime(2026, 8, 2, 6, 3, 26, 805420)}

# %%
twin.simulate_increase(20)
# Out:
# <xarray.Dataset> Size: 25MB
# Dimensions:    (TIME: 365, LATITUDE: 129, LONGITUDE: 135)
# Coordinates:
#   * TIME       (TIME) datetime64[ns] 3kB 2025-01-01 2025-01-02 ... 2025-12-31
#   * LATITUDE   (LATITUDE) float64 1kB 6.5 6.75 7.0 7.25 ... 38.0 38.25 38.5
#   * LONGITUDE  (LONGITUDE) float64 1kB 66.5 66.75 67.0 ... 99.5 99.75 100.0
# Data variables:
#     RAINFALL   (TIME, LATITUDE, LONGITUDE) float32 25MB nan nan nan ... nan nan
# Attributes:
#     history:      FERRET V6.82    9-Apr-26
#     Conventions:  CF-1.0

# %%
twin.reset_simulation()

# %%
twin.simulate_dry_spell(
    "2025-06-01",
    "2025-06-10"
)
# Out:
# <xarray.Dataset> Size: 25MB
# Dimensions:    (TIME: 365, LATITUDE: 129, LONGITUDE: 135)
# Coordinates:
#   * TIME       (TIME) datetime64[ns] 3kB 2025-01-01 2025-01-02 ... 2025-12-31
#   * LATITUDE   (LATITUDE) float64 1kB 6.5 6.75 7.0 7.25 ... 38.0 38.25 38.5
#   * LONGITUDE  (LONGITUDE) float64 1kB 66.5 66.75 67.0 ... 99.5 99.75 100.0
# Data variables:
#     RAINFALL   (TIME, LATITUDE, LONGITUDE) float32 25MB ...
# Attributes:
#     history:      FERRET V6.82    9-Apr-26
#     Conventions:  CF-1.0

# %%
twin.reset_state()

twin.current_state()
# Out:
# {'latitude': None,
#  'longitude': None,
#  'date': None,
#  'rainfall': None,
#  'last_updated': None}
