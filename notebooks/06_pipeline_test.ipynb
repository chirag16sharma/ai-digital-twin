# %%
from pathlib import Path
import sys

project_root = Path.cwd().parent
sys.path.append(str(project_root))

from src.pipeline.data_pipeline import DataPipeline

pipeline = DataPipeline(
    input_file=project_root / "data" / "raw" / "imd_rainfall" / "rainfall2025.nc",
    output_file=project_root / "data" / "processed" / "rainfall_ai_ready.nc"
)

pipeline.run()
# Out:
# ...
# STARTING DATA PIPELINE
# ...
# IMD DATASET SUMMARY
# ...
# Time Steps : 365
# Latitudes  : 129
# Longitudes : 135
#
# Date Range
# 2007-01-01T00:00:00.000000000 to 2007-12-31T00:00:00.000000000
#
# Rainfall Statistics
# Minimum : 0.00 mm
# Maximum : 550.44 mm
# Average : 3.20 mm
# ...
# DATA QUALITY REPORT
# ...
# Total Values      : 6356475
# Missing Values    : 4544615
# Negative Values   : 0
#
# Pipeline completed successfully!
# Saved to: s:\ai-digital-twin\data\processed\rainfall_ai_ready.nc

# %%
import src.pipeline.data_pipeline as dp

print(dp.__file__)
print(dir(dp))
# Out:
# s:\ai-digital-twin\src\pipeline\data_pipeline.py
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__']

# %%
from pathlib import Path

project_root = Path.cwd().parent

pipeline_file = project_root / "src" / "pipeline" / "data_pipeline.py"

print(pipeline_file)
print(pipeline_file.exists())
# Out:
# s:\ai-digital-twin\src\pipeline\data_pipeline.py
# True

# %%
import traceback
import importlib

try:
    import src.pipeline.data_pipeline as dp
    importlib.reload(dp)
    print("Module loaded successfully!")
    print(dir(dp))
except Exception:
    traceback.print_exc()
# Out:
# Module loaded successfully!
# ['DataCleaner', 'DataExplorer', 'DataPipeline', 'FeatureEngineer', 'IMDLoader', 'Path', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__']
