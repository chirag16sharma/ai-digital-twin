# %%
from pathlib import Path
import sys

project_root = Path.cwd().parent

sys.path.append(str(project_root))

from src.twin.state_manager import StateManager

# %%
state = StateManager()

# %%
state.display_state()
# Out:
# ==================================================
# CURRENT DIGITAL TWIN STATE
# ==================================================
# latitude       : None
# longitude      : None
# date           : None
# rainfall       : None
# last_updated   : None

# %%
state.set_date("2025-07-15")

state.display_state()
# Out:
# ==================================================
# CURRENT DIGITAL TWIN STATE
# ==================================================
# latitude       : None
# longitude      : None
# date           : 2025-07-15
# rainfall       : None
# last_updated   : 2026-08-02 05:37:06.727390

# %%
state.set_location(
    12.9716,
    77.5946
)

state.display_state()
# Out:
# ==================================================
# CURRENT DIGITAL TWIN STATE
# ==================================================
# latitude       : 12.9716
# longitude      : 77.5946
# date           : 2025-07-15
# rainfall       : None
# last_updated   : 2026-08-02 05:37:08.917268

# %%
state.update_state(
    latitude=28.6139,
    longitude=77.2090,
    date="2025-08-10",
    rainfall=45.8
)

state.display_state()
# Out:
# ==================================================
# CURRENT DIGITAL TWIN STATE
# ==================================================
# latitude       : 28.6139
# longitude      : 77.209
# date           : 2025-08-10
# rainfall       : 45.8
# last_updated   : 2026-08-02 05:37:10.829133

# %%
state.clear_state()

state.display_state()
# Out:
# ==================================================
# CURRENT DIGITAL TWIN STATE
# ==================================================
# latitude       : None
# longitude      : None
# date           : None
# rainfall       : None
# last_updated   : None

# %%
state.set_date("2025-07-15")

state.display_state()
# Out:
# ==================================================
# CURRENT DIGITAL TWIN STATE
# ==================================================
# latitude       : None
# longitude      : None
# date           : 2025-07-15
# rainfall       : None
# last_updated   : 2026-08-02 05:37:14.463449

# %%
state.get_state()
# Out:
# {'latitude': None,
#  'longitude': None,
#  'date': '2025-07-15',
#  'rainfall': None,
#  'last_updated': datetime.datetime(2026, 8, 2, 5, 37, 14, 463449)}
